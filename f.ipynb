# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#pd.pandas.set_option('display.max_columns',None)
#pd.pandas.set_option('display.max_rows',None)
pd.options.display.max_rows=100
pd.options.display.max_columns=70
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/LENOVO X1 YOGA/Downloads/fifa_cleaned (1).csv")

# %%
df.head()
# Out:
#        id          name                       full_name  birth_date  age  \
# 0  158023      L. Messi  Lionel Andrés Messi Cuccittini  1987-06-24   31
# 1  190460    C. Eriksen    Christian  Dannemann Eriksen  1992-02-14   27
# 2  195864      P. Pogba                      Paul Pogba  1993-03-15   25
# 3  198219    L. Insigne                 Lorenzo Insigne  1991-06-04   27
# 4  201024  K. Koulibaly               Kalidou Koulibaly  1991-06-20   27
#
#    height_cm  weight_kgs  positions nationality  overall_rating  potential  \
# 0     170.18        72.1   CF,RW,ST   Argentina              94         94
# 1     154.94        76.2  CAM,RM,CM     Denmark              88         89
# 2     190.50        83.9     CM,CAM      France              88         91
# 3     162.56        59.0      LW,ST       Italy              88         88
# 4     187.96        88.9         CB     Senegal              88         91
#
#     value_euro  wage_euro preferred_foot  international_reputation(1-5)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 92 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             17954 non-null  int64
#  1   name                           17954 non-null  object
#  2   full_name                      17954 non-null  object
#  3   birth_date                     17954 non-null  object
#  4   age                            17954 non-null  int64
#  5   height_cm                      17954 non-null  float64
#  6   weight_kgs                     17954 non-null  float64
#  7   positions                      17954 non-null  object
#  8   nationality                    17954 non-null  object
#  9   overall_rating                 17954 non-null  int64
#  10  potential                      17954 non-null  int64
#  11  value_euro                     17699 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id           age     height_cm    weight_kgs  \
# count   17954.000000  17954.000000  17954.000000  17954.000000
# mean   215411.087780     25.565445    174.946921     75.301047
# std     29758.387106      4.705708     14.029449      7.083684
# min        16.000000     17.000000    152.400000     49.900000
# 25%    201117.250000     22.000000    154.940000     69.900000
# 50%    222919.000000     25.000000    175.260000     74.800000
# 75%    237613.500000     29.000000    185.420000     79.800000
# max    247607.000000     46.000000    205.740000    110.200000
#
#        overall_rating     potential    value_euro      wage_euro  \
# count    17954.000000  17954.000000  1.769900e+04   17708.000000
# mean        66.240169     71.430935  2.479280e+06    9902.134628
# std          6.963730      6.131339  5.687014e+06   21995.593750
# min         47.000000     48.000000  1.000000e+04    1000.000000
# 25%         62.000000     67.000000  3.250000e+05    1000.000000
# ...

# %%
df.shape
# Out:
# (17954, 92)

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# work_rate                            0
# body_type                            0
# release_clause_euro               1837
# club_team                           14
# club_rating                         14
# club_position                       14
# club_jersey_number                  14
# ...

# %%
fdg = df.select_dtypes('number')

# %%
fdg
# Out:
#            id  age  height_cm  weight_kgs  overall_rating  potential  \
# 0      158023   31     170.18        72.1              94         94
# 1      190460   27     154.94        76.2              88         89
# 2      195864   25     190.50        83.9              88         91
# 3      198219   27     162.56        59.0              88         88
# 4      201024   27     187.96        88.9              88         91
# ...       ...  ...        ...         ...             ...        ...
# 17949  204322   25     175.26        74.8              67         70
# 17950  239762   23     182.88        79.8              59         67
# 17951  235155   22     185.42        89.8              59         67
# 17952  244883   21     175.26        64.9              59         71
# 17953  247187   19     190.50        79.8              59         75
#
#         value_euro  wage_euro  international_reputation(1-5)  weak_foot(1-5)  \
# ...

# %%
for x in fdg.columns:
    sns.displot(data=df,x=x,kde=True)

# %%
null=[x for x in fdg.columns if fdg[x].isnull().sum()>0]

# %%
a=fdg[null]

# %%
a
# Out:
#         value_euro  wage_euro  release_clause_euro  club_rating  \
# 0      110500000.0   565000.0          226500000.0         86.0
# 1       69500000.0   205000.0          133800000.0         83.0
# 2       73000000.0   255000.0          144200000.0         82.0
# 3       62000000.0   165000.0          105400000.0         82.0
# 4       60000000.0   135000.0          106500000.0         82.0
# ...            ...        ...                  ...          ...
# 17949     975000.0     3000.0            1800000.0         67.0
# 17950     190000.0     1000.0             295000.0         65.0
# 17951     170000.0     1000.0             289000.0         69.0
# 17952     280000.0     4000.0             532000.0         74.0
# 17953     325000.0     2000.0             626000.0         71.0
#
#        club_jersey_number  national_rating  national_jersey_number
# 0                    10.0             82.0                    10.0
# ...

# %%
for i in a.columns:
    sns.displot(x=a[i], kde=True)
    plt.show()

# %%
for x in range(1,7):
    sns.boxplot(a.iloc[:,x])
    plt.show()

# %%
a.shape
# Out:
# (17954, 7)

# %%
df['value_euro'].fillna(df['value_euro'].mode()[0],inplace=True)
df['release_clause_euro'].fillna(df['release_clause_euro'].mode()[0],inplace=True)
df['wage_euro'].fillna(df['wage_euro'].mode()[0],inplace=True)
df['club_rating'].fillna(df['club_rating'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                           0
# wage_euro                            0
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# work_rate                            0
# body_type                            0
# release_clause_euro                  0
# club_team                           14
# club_rating                          0
# club_position                       14
# club_jersey_number                  14
# ...

# %%
df.drop(['national_team','national_rating','national_team_position','national_jersey_number','id','birth_date'],axis=1,inplace=True)

# %%
df1=df.drop(['tags','traits','LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB'],axis=1)

# %%
df1.columns
# Out:
# Index(['name', 'full_name', 'age', 'height_cm', 'weight_kgs', 'positions',
#        'nationality', 'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'international_reputation(1-5)', 'weak_foot(1-5)',
#        'skill_moves(1-5)', 'work_rate', 'body_type', 'release_clause_euro',
#        'club_team', 'club_rating', 'club_position', 'club_jersey_number',
#        'club_join_date', 'contract_end_year', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'freekick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'composure',
#        'marking', 'standing_tackle', 'sliding_tackle', 'GK_diving',
#        'GK_handling', 'GK_kicking', 'GK_positioning', 'GK_reflexes'],
# ...

# %%
df1
# Out:
#                  name                         full_name  age  height_cm  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini   31     170.18
# 1          C. Eriksen      Christian  Dannemann Eriksen   27     154.94
# 2            P. Pogba                        Paul Pogba   25     190.50
# 3          L. Insigne                   Lorenzo Insigne   27     162.56
# 4        K. Koulibaly                 Kalidou Koulibaly   27     187.96
# ...               ...                               ...  ...        ...
# 17949     R. McKenzie                    Rory  McKenzie   25     175.26
# 17950       M. Sipľak                     Michal Sipľak   23     182.88
# 17951      J. Bekkema                       Jan Bekkema   22     185.42
# 17952      A. Al Yami               Abdulrahman Al Yami   21     175.26
# 17953  Júnior Brumado  José Francisco dos Santos Júnior   19     190.50
#
#        weight_kgs  positions   nationality  overall_rating  potential  \
# ...

# %%
df1.columns
# Out:
# Index(['name', 'full_name', 'age', 'height_cm', 'weight_kgs', 'positions',
#        'nationality', 'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'international_reputation(1-5)', 'weak_foot(1-5)',
#        'skill_moves(1-5)', 'work_rate', 'body_type', 'release_clause_euro',
#        'club_team', 'club_rating', 'club_position', 'club_jersey_number',
#        'club_join_date', 'contract_end_year', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'freekick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'composure',
#        'marking', 'standing_tackle', 'sliding_tackle', 'GK_diving',
#        'GK_handling', 'GK_kicking', 'GK_positioning', 'GK_reflexes'],
# ...

# %%
df1.isnull().sum()
# Out:
# name                                0
# full_name                           0
# age                                 0
# height_cm                           0
# weight_kgs                          0
# positions                           0
# nationality                         0
# overall_rating                      0
# potential                           0
# value_euro                          0
# wage_euro                           0
# preferred_foot                      0
# international_reputation(1-5)       0
# weak_foot(1-5)                      0
# skill_moves(1-5)                    0
# work_rate                           0
# body_type                           0
# release_clause_euro                 0
# club_team                          14
# club_rating                         0
# club_position                      14
# club_jersey_number                 14
# club_join_date                   1936
# contract_end_year                 361
# crossing                            0
# ...

# %%
df1.shape
# Out:
# (17954, 58)

# %%
plt.figure(figsize=(10,8))
x=sns.countplot(data=df1,x='age')
x.set_xlabel(xlabel='Age of the players',fontsize=16)
x.set_title(label = 'Distribution of age of the players',fontsize=20)
plt.show()

# %%
o = pd.DataFrame(df1.groupby(['age'])['overall_rating'].mean())
p = pd.DataFrame(df1.groupby(['age'])['potential'].mean())

# %%
m = pd.merge(o,p,on = 'age',how = 'inner')
m['age'] = m.index 
m
# Out:
#      overall_rating  potential  age
# age
# 17        55.478528  74.889571   17
# 18        56.984283  73.950884   18
# 19        58.825496  73.820272   19
# 20        60.648908  73.274236   20
# 21        62.863400  73.314031   21
# 22        64.339706  73.014706   22
# 23        65.516350  72.546768   23
# 24        66.943208  72.427475   24
# 25        67.598160  71.521472   25
# 26        68.453526  70.981571   26
# 27        68.992413  70.025038   27
# 28        69.050089  69.477639   28
# 29        69.403473  69.583248   29
# 30        69.519597  69.561030   30
# 31        69.784615  69.784615   31
# 32        69.724522  69.724522   32
# 33        69.597849  69.597849   33
# 34        70.009317  70.009317   34
# 35        69.384181  69.384181   35
# 36        68.290909  68.290909   36
# 37        67.929293  67.929293   37
# 38        69.053571  69.053571   38
# 39        68.354839  68.354839   39
# 40        66.066667  66.066667   40
# 41        69.600000  69.600000   41
# ...

# %%
m.reset_index(drop=True,inplace=True)
m
# Out:
#     overall_rating  potential  age
# 0        55.478528  74.889571   17
# 1        56.984283  73.950884   18
# 2        58.825496  73.820272   19
# 3        60.648908  73.274236   20
# 4        62.863400  73.314031   21
# 5        64.339706  73.014706   22
# 6        65.516350  72.546768   23
# 7        66.943208  72.427475   24
# 8        67.598160  71.521472   25
# 9        68.453526  70.981571   26
# 10       68.992413  70.025038   27
# 11       69.050089  69.477639   28
# 12       69.403473  69.583248   29
# 13       69.519597  69.561030   30
# 14       69.784615  69.784615   31
# 15       69.724522  69.724522   32
# 16       69.597849  69.597849   33
# 17       70.009317  70.009317   34
# 18       69.384181  69.384181   35
# 19       68.290909  68.290909   36
# 20       67.929293  67.929293   37
# 21       69.053571  69.053571   38
# 22       68.354839  68.354839   39
# 23       66.066667  66.066667   40
# 24       69.600000  69.600000   41
# 25       66.500000  66.500000   42
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot('age','overall_rating',data=m,marker='.',label='overall')
plt.plot('age','potential',data=m,marker = '+',label='potential')
plt.xlabel('overall rating')
plt.ylabel('average potential growth by age')
plt.legend();

# %%
df1.head()
# Out:
#            name                       full_name  age  height_cm  weight_kgs  \
# 0      L. Messi  Lionel Andrés Messi Cuccittini   31     170.18        72.1
# 1    C. Eriksen    Christian  Dannemann Eriksen   27     154.94        76.2
# 2      P. Pogba                      Paul Pogba   25     190.50        83.9
# 3    L. Insigne                 Lorenzo Insigne   27     162.56        59.0
# 4  K. Koulibaly               Kalidou Koulibaly   27     187.96        88.9
#
#    positions nationality  overall_rating  potential   value_euro  wage_euro  \
# 0   CF,RW,ST   Argentina              94         94  110500000.0   565000.0
# 1  CAM,RM,CM     Denmark              88         89   69500000.0   205000.0
# 2     CM,CAM      France              88         91   73000000.0   255000.0
# 3      LW,ST       Italy              88         88   62000000.0   165000.0
# 4         CB     Senegal              88         91   60000000.0   135000.0
#
# ...

# %%
a = df1.nationality.value_counts().values

# %%
plt.figure(figsize=(15,35))
sns.countplot(data=df1,y='nationality')
# Out:
# <AxesSubplot:xlabel='count', ylabel='nationality'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df1,x='potential')
# Out:
# <AxesSubplot:xlabel='potential', ylabel='count'>

# %%
sns.countplot(data=df,x='preferred_foot')
# Out:
# <AxesSubplot:xlabel='preferred_foot', ylabel='count'>

# %%
sns.countplot(data=df,x='international_reputation(1-5)')
# Out:
# <AxesSubplot:xlabel='international_reputation(1-5)', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='work_rate')
# Out:
# <AxesSubplot:xlabel='work_rate', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=df1,x='body_type')
# Out:
# <AxesSubplot:xlabel='body_type', ylabel='count'>

# %%
plt.figure(figsize=(8,12))
sns.countplot(data=df,y='club_rating')
# Out:
# <AxesSubplot:xlabel='count', ylabel='club_rating'>

# %%
df1.columns
# Out:
# Index(['name', 'full_name', 'age', 'height_cm', 'weight_kgs', 'positions',
#        'nationality', 'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'international_reputation(1-5)', 'weak_foot(1-5)',
#        'skill_moves(1-5)', 'work_rate', 'body_type', 'release_clause_euro',
#        'club_team', 'club_rating', 'club_position', 'club_jersey_number',
#        'club_join_date', 'contract_end_year', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'freekick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'composure',
#        'marking', 'standing_tackle', 'sliding_tackle', 'GK_diving',
#        'GK_handling', 'GK_kicking', 'GK_positioning', 'GK_reflexes'],
# ...

# %%
df1['BMI']=df1['weight_kgs']/(df1['height_cm']/100)**2

# %%
df1['BMI']
# Out:
# 0        24.895349
# 1        31.741531
# 2        23.119157
# 3        22.326705
# 4        25.163491
#            ...
# 17949    24.352076
# 17950    23.860001
# 17951    26.119399
# 17952    21.129007
# 17953    21.989377
# Name: BMI, Length: 17954, dtype: float64

# %%
df1.head()
# Out:
#            name                       full_name  age  height_cm  weight_kgs  \
# 0      L. Messi  Lionel Andrés Messi Cuccittini   31     170.18        72.1
# 1    C. Eriksen    Christian  Dannemann Eriksen   27     154.94        76.2
# 2      P. Pogba                      Paul Pogba   25     190.50        83.9
# 3    L. Insigne                 Lorenzo Insigne   27     162.56        59.0
# 4  K. Koulibaly               Kalidou Koulibaly   27     187.96        88.9
#
#    positions nationality  overall_rating  potential   value_euro  wage_euro  \
# 0   CF,RW,ST   Argentina              94         94  110500000.0   565000.0
# 1  CAM,RM,CM     Denmark              88         89   69500000.0   205000.0
# 2     CM,CAM      France              88         91   73000000.0   255000.0
# 3      LW,ST       Italy              88         88   62000000.0   165000.0
# 4         CB     Senegal              88         91   60000000.0   135000.0
#
# ...

# %%
df1.drop(['name','club_join_date'],axis=1,inplace=True)

# %%
df1.isnull().sum()
# Out:
# full_name                          0
# age                                0
# height_cm                          0
# weight_kgs                         0
# positions                          0
# nationality                        0
# overall_rating                     0
# potential                          0
# value_euro                         0
# wage_euro                          0
# preferred_foot                     0
# international_reputation(1-5)      0
# weak_foot(1-5)                     0
# skill_moves(1-5)                   0
# work_rate                          0
# body_type                          0
# release_clause_euro                0
# club_team                         14
# club_rating                        0
# club_position                     14
# club_jersey_number                14
# contract_end_year                361
# crossing                           0
# finishing                          0
# heading_accuracy                   0
# ...

# %%
sns.relplot(data=df1,x = 'overall_rating',y = 'value_euro',palette = 'viridis',hue='age',size='BMI',sizes=(15,200),aspect=2)
plt.title('overall rating vs value in euros',fontsize=20)
# Out:
# Text(0.5, 1.0, 'overall rating vs value in euros')

# %%
sns.relplot(data=df1,x='overall_rating',y='potential',palette='viridis',hue='age',size='BMI',sizes=(15,200),aspect=2)

# %%
sns.relplot(x=)
# Out:
#   Input In [48]
#     sns.relplot(x=)
#                   ^
# SyntaxError: invalid syntax

# %%
 sns.countplot('preferred_foot',data=df1)
plt.title('  count of players preferred foot',fontsize=20)
Right,Left = df1.preferred_foot.value_counts()
print('left preferred',Left)
print('Right preferred ',Right)
# Out:
# left preferred 4173
# Right preferred  13781

# %%
sns.countplot('international_reputation(1-5)',data=df1)

# %%
plt.figure(dpi=125)
sns.distplot(a=df1['age'],bins=20,kde= True,color='red')
plt.axvline(x = np.mean(df1['age']),c='green',ls='--',label='Mean age of all players')
plt.legend()
plt.xlabel('Age')
plt.ylabel('count')
plt.title('Distribution of age')
plt.show()

# %%
sns.distplot(a = df1['BMI'],kde=False,bins=20,color='green')
plt.axvline(x=np.mean(df1['BMI']),c='black',ls='--',label='Mean BMI of all players')
plt.legend()
plt.title('Distribution of BMI')
plt.show()

# %%
plt.figure(figsize=(22,12))
sns.countplot(x='nationality',data=df1.head(20),palette='CMRmap')
plt.title('which country has max players in top 20',fontsize=30)
# Out:
# Text(0.5, 1.0, 'which country has max players in top 20')

# %%
plt.figure(figsize=(22,12))
sns.countplot(x='club_team',data=df1.head(20),palette ='CMRmap')
plt.title('which club team has max players in top 20',fontsize=30)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x ='club_position',data=df1.head(20),palette='CMRmap' )
plt.title('Which type of player comes most in Top 20',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Which type of player comes most in Top 20')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='age',data=df1.head(20),palette='Blues')
plt.title('which age belongs to max players in top 20',fontsize=16)
# Out:
# Text(0.5, 1.0, 'which age belongs to max players in top 20')

# %%
sns.scatterplot(x='age',y='potential',hu)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='value_euro',y='wage_euro',data=df1,hue='age',palette = 'CMRmap')
# Out:
# <AxesSubplot:xlabel='value_euro', ylabel='wage_euro'>

# %%
pot_play=df1[['full_name','age','nationality','club_team','potential','club_position','overall_rating','value_euro','release_clause_euro']]
fig=plt.scatter(pot_play,x='age',y='potential',size='potential',color='age',hover_data=['name','age','nationality','club_position','overall_rating','value_euro','release_clause_euro'],title='Age vs Maximum Potential Distribution of the young Players')
fig.show()

# %%
labels=df1['skill_moves(1-5)'].value_counts().keys()
plt.pie(x=df1['skill_moves(1-5)'].value_counts(),autopct="%.1f%%", labels=labels, explode=[0.05]*5, pctdistance=0.5)
plt.title("Proportion of players by skill moves", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Proportion of players by skill moves')

# %%
len(df1.groupby('nationality')['full_name'].get_group("Mali"))

# %%
asdfghjklll;['']
